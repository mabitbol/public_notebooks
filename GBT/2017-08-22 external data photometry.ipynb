# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astropy.io import fits
import healpy as hp

# %%
kboltz=1.3806503e-23 #MKS
clight=299792458.0 #MKS
hplanck=6.626068e-34 #MKS
TCMB = 2.72548 #Kelvin
d2r = np.pi / 180.

# %%
haslam0408 = hp.read_map('../externaldata/haslam408_dsds_Remazeilles2014.fits', verbose=False)
haslam0408 = hp.ud_grade(hp.smoothing(haslam0408, fwhm=1.*d2r), 512)
# Out:
# Sigma is 25.479654 arcmin (0.007412 rad)
# -> fwhm is 60.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
reich1420 = hp.read_map('../externaldata/STOCKERT+VILLA-ELISA_1420MHz_1_256.fits', verbose=False)
#reich1420 = hp.ud_grade(hp.smoothing(reich1420, fwhm=1.*d2r), 512)

# %%
planck30bpc = hp.read_map('../externaldata/LFI_SkyMap_030-BPassCorrected-field-IQU_0256_R2.01_full.fits', verbose=False)
#planck30bpc = hp.ud_grade(hp.smoothing(planck30bpc, fwhm=1.*d2r), 512)

# %%
planck30 = hp.read_map('../externaldata/LFI_SkyMap_030-field-IQU_1024_R2.01_full.fits', verbose=False)
#planck30 = hp.ud_grade(hp.smoothing(planck30, fwhm=1.*d2r), 512)

# %%
planck44bpc = hp.read_map('../externaldata/LFI_SkyMap_044-BPassCorrected-field-IQU_0256_R2.01_full.fits', verbose=False)
#planck44bpc = hp.ud_grade(hp.smoothing(planck44bpc, fwhm=1.*d2r), 512)

# %%
planck44 = hp.read_map('../externaldata/LFI_SkyMap_044-field-IQU_1024_R2.01_full.fits', verbose=False)
#planck44 = hp.ud_grade(hp.smoothing(planck44, fwhm=1.*d2r), 512)

# %%
planck70bpc = hp.read_map('../externaldata/LFI_SkyMap_070-BPassCorrected-field-IQU_0256_R2.01_full.fits', verbose=False)
planck70bpc = hp.ud_grade(hp.smoothing(planck70bpc, fwhm=1.*d2r), 512)
# Out:
# Sigma is 25.479654 arcmin (0.007412 rad)
# -> fwhm is 60.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
planck70 = hp.read_map('../externaldata/LFI_SkyMap_070-field-IQU_1024_R2.01_full.fits', verbose=False)
#planck70 = hp.ud_grade(hp.smoothing(planck70, fwhm=1.*d2r), 512)

# %%
planck100 = hp.read_map('../externaldata/HFI_SkyMap_100-field-IQU_2048_R2.02_full.fits', verbose=False)
#planck100 = hp.ud_grade(hp.smoothing(planck100, fwhm=1.*d2r), 512)

# %%
planck143 = hp.read_map('../externaldata/HFI_SkyMap_143-field-IQU_2048_R2.02_full.fits', verbose=False)
planck143 = hp.ud_grade(hp.smoothing(planck143, fwhm=1.*d2r), 512)
# Out:
# Sigma is 25.479654 arcmin (0.007412 rad)
# -> fwhm is 60.000000 arcmin
# Sigma is 0.000000 arcmin (0.000000 rad)
# -> fwhm is 0.000000 arcmin

# %%
planck217 = hp.read_map('../externaldata/HFI_SkyMap_217-field-IQU_2048_R2.02_full.fits', verbose=False)
#planck217 = hp.ud_grade(hp.smoothing(planck217, fwhm=1.*d2r), 512)

# %%
planck353 = hp.read_map('../externaldata/HFI_SkyMap_353-field-IQU_2048_R2.02_full.fits', verbose=False)
#planck353 = hp.ud_grade(hp.smoothing(planck353, fwhm=1.*d2r), 512)

# %%
planck545 = hp.read_map('../externaldata/HFI_SkyMap_545-field-Int_2048_R2.02_full.fits', verbose=False)
#planck545 = hp.ud_grade(hp.smoothing(planck545, fwhm=1.*d2r), 512)

# %%
planck857 = hp.read_map('../externaldata/HFI_SkyMap_857-field-Int_2048_R2.02_full.fits', verbose=False)
#planck857 = hp.ud_grade(hp.smoothing(planck857, fwhm=1.*d2r), 512)

# %%
wmap23 = hp.read_map('../externaldata/wmap_band_smth_imap_r9_9yr_K_v5.fits', verbose=False) * 1.e-3

# %%
wmap33 = hp.read_map('../externaldata/wmap_band_smth_imap_r9_9yr_Ka_v5.fits', verbose=False) * 1.e-3

# %%
wmap40 = hp.read_map('../externaldata/wmap_band_smth_imap_r9_9yr_Q_v5.fits', verbose=False) * 1.e-3

# %%
wmap60 = hp.read_map('../externaldata/wmap_band_smth_imap_r9_9yr_V_v5.fits', verbose=False) * 1.e-3

# %%
wmap90 = hp.read_map('../externaldata/wmap_band_smth_imap_r9_9yr_W_v5.fits', verbose=False) * 1.e-3

# %%
lonc = 107.2
latc = 5.2
lonra = [lonc-2., lonc+2.]
latra = [latc-2., latc+2.]

# %%
hp.cartview(haslam0408, lonra=lonra, latra=latra)

# %%
hp.cartview(reich1420, lonra=lonra, latra=latra)

# %%
hp.cartview(wmap23, lonra=lonra, latra=latra)

# %%
hp.cartview(planck30, lonra=lonra, latra=latra)

# %%
hp.cartview(wmap33, lonra=lonra, latra=latra)

# %%
hp.cartview(wmap40, lonra=lonra, latra=latra)

# %%
hp.cartview(planck44, lonra=lonra, latra=latra)

# %%
hp.cartview(wmap60, lonra=lonra, latra=latra)

# %%
hp.cartview(planck70, lonra=lonra, latra=latra)

# %%
hp.cartview(wmap90, lonra=lonra, latra=latra)

# %%
hp.cartview(planck100, lonra=lonra, latra=latra)

# %%
hp.cartview(planck143, lonra=lonra, latra=latra)

# %%
hp.cartview(planck217, lonra=lonra, latra=latra)

# %%
hp.cartview(planck353, lonra=lonra, latra=latra)

# %%
hp.cartview(planck545, lonra=lonra, latra=latra)

# %%
hp.cartview(planck857, lonra=lonra, latra=latra)

# %%
# explanatory supplement table 4 conversion factors!!!!!!!
pfreqs = np.array([30, 44, 70, 100, 143, 217, 353, 545, 857])
kcmb2krj = np.array([ 0.9487, 0.9328, 0.8484, 0.7942, 0.5921, 0.3343, 0.0751])
kcmb2krj_2 = np.array([ 0.979328, 0.95121302, 0.88140690, 0.76581996, 0.59714682, 0.31573332, 0.071041398])
krj2mjy = np.array([24.845597, 59.666236, 151.73238, 306.81118, 627.39818, 1444.7432, 3823.1434])

# %%
# conversion factors HFI
#https://www.aanda.org/articles/aa/pdf/2014/11/aa21531-13.pdf
# brightness temperature to flux density MJy / sr
planckfreqs = np.array([ 100, 143, 217, 353, 545, 857])
hficonversion = np.array([ 0.0032548074, 0.0015916707, 0.00069120334, 0.00026120163, 0.00010958025, 0.000044316316])

# %%
planckconverions = np.array([ 27.0175, 56.5941, 132.857, 238.815, 380.0, 483.82, 296.877, 57.1943, 1.43907])

# %%
# haslam is in mK

# %%
lonc2 = 160.26
latc2 = -18.62

# %%
x = np.copy(wmap23)
nside = hp.get_nside(x)
vecc = hp.rotator.dir2vec(lonc2, latc2, lonlat=True)
rmask = hp.query_disc(nside, vecc, 1.*d2r)
amaskout = set(hp.query_disc(nside, vecc, 2.*d2r))
amaskin = set(hp.query_disc(nside, vecc, (80./60.)*d2r))
amask = np.array(list(amaskout.difference(amaskin)))

# %%
nu = 408e6 
y = x * 2 * nu * nu * kboltz / clight**2 * 1e-3 * hp.nside2pixarea(nside) * 1.e26

# %%
rdata = y[rmask]
adata = y[amask]

# %%
print np.sum(rdata - np.median(adata)), np.std(adata) * np.sqrt(len(rdata))
# Out:
# -0.00214391178182 0.000397384576493

# %%
nu = 22.8e9
X = hplanck * nu / (kboltz * TCMB) 
conversion = 2. * kboltz * nu**2 / clight**2 * np.exp(X) * (X / (np.exp(X) - 1.))**2 * hp.nside2pixarea(nside) * 1.e26

# %%
y = x * conversion

# %%
nu = 22.8e9 
y = x * 2 * nu * nu * kboltz / clight**2 * hp.nside2pixarea(nside) * 1.e26

# %%
rdata = y[rmask]
adata = y[amask]

# %%
print np.sum(rdata - np.median(adata)), np.std(adata) * np.sqrt(len(rdata))
# Out:
# 21.3345563854 0.335317927668

# %%
hp.cartview(x, lonra=lonra, latra=latra)

# %%
y = x * planckconverions[2] * hp.nside2pixarea(nside) * 1e6

# %%
rdata = y[rmask]
adata = y[amask]

# %%
print np.sum(rdata - np.median(adata)), np.std(adata) * np.sqrt(len(rdata))
# Out:
# 24.2921391963 0.771174025967

# %%
hp.cartview(y, lonra=lonra, latra=latra)

# %%
rdata = y[rpix]
adata = y[apix]

# %%
print np.sum(rdata - np.median(adata)), np.std(adata) * np.sqrt(len(rdata))
# Out:
# 24.1203999993 0.768116473913

# %%
y = planck857 * hp.nside2pixarea(512) * 1.e6

# %%
nside = hp.get_nside(haslam0408)
indx = np.arange(hp.nside2npix(nside))
theta, phi = hp.pix2ang(nside, indx)
lats = (np.pi / 2. - theta) / d2r 
lons = phi / d2r

radius = np.sqrt( (lats - latc)**2 + (lons - lonc)**2 )
rmask = radius < 1.
amask = (radius > 80./60.) & (radius < 2.)

rpix = hp.ang2pix(nside, theta[rmask], phi[rmask])
apix = hp.ang2pix(nside, theta[amask], phi[amask])
