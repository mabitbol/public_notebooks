# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob
from scipy.ndimage.filters import gaussian_filter
from scipy.optimize import curve_fit

# %%
import healpy as hp

# %%
from astropy import coordinates
from astropy import units as u
from astropy.coordinates import ICRS

# %%
from astropy.io import fits

# %%
from __future__ import unicode_literals

figsize(10,8)

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
    
rcParams['xtick.labelsize'] = 20
rcParams['xtick.major.size'] = 10
rcParams['xtick.major.width'] = 1
rcParams['xtick.major.pad'] = 10
rcParams['xtick.minor.size'] = 5
rcParams['xtick.minor.width'] = 1

rcParams['ytick.labelsize'] = 20
rcParams['ytick.major.size'] = 10
rcParams['ytick.major.width'] = 1
rcParams['ytick.major.pad'] = 10
rcParams['ytick.minor.size'] = 5
rcParams['ytick.minor.width'] = 1

rcParams['legend.fontsize'] = 12
rcParams['legend.borderaxespad'] = 2

rcParams['axes.labelsize'] = 24
rcParams['axes.titlesize'] = 24

# %%
x = fits.open('/home/mabitbol/GBT-S140/externaldata/destripingdata_bankA_session5.fits')

# %%
banka = x[0].data
#banka[banka==0] = np.nan

# %%
figure()
imshow(banka, origin='lower')
clim(-.15, .15)
colorbar()

# %%
figure()
pc = pcolormesh(rabinsc, decbinsc, signal * 1000.)
#pc = pcolormesh(rabinsc, decbinsc, outerregion)
clim(-12, 12)
cb = colorbar()
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cb.set_label('$\mathrm{Flux}\ (mJy / pixel)$')
grid(alpha=0.7)
title('$6.2~GHz$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8a95049d8d74> in <module>()
#       1 figure()
# ----> 2 pc = pcolormesh(rabinsc, decbinsc, signal * 1000.)
#       3 #pc = pcolormesh(rabinsc, decbinsc, outerregion)
#       4 clim(-12, 12)
#       5 cb = colorbar()
#
# NameError: name 'rabinsc' is not defined

# %%
freqs = [4.575, 5.625, 6.125, 7.175]
banks = ['A', 'B', 'C', 'D']

# %%
def naive_map(data,ra,dec,ra_num_bins=60,dec_num_bins=50):
    ra_bins = np.linspace(ra.min(),ra.max(),ra_num_bins)
    dec_bins = np.linspace(dec.min(),dec.max(),dec_num_bins)
    p,_,_ = np.histogram2d(ra,dec,bins=(ra_bins,dec_bins),weights=data)
    hits,_,_ = np.histogram2d(ra,dec,bins=(ra_bins,dec_bins))
    return p.T, hits.T, ra_bins, dec_bins

# %%
def calculate_sflux_gal(bank='A', session='5', doplot=True, pixbeam=1., smth=0, removeplane=True):
    dataf = np.load('/home/mabitbol/GBT-S140/datamaps/tod'+bank+'_'+session+'.npz')
    tmask = dataf['tmask']
    ras = dataf['ras'][tmask]
    decs = dataf['decs'][tmask]
    calibrated = dataf['calibrated'][tmask]
    
    tmask2 = ~np.isnan(calibrated)
    ras = ras[tmask2]
    decs = decs[tmask2]
    calibrated = calibrated[tmask2] 
    
    c = coordinates.SkyCoord(frame='icrs', ra=ras*u.degree, dec=decs*u.degree)
    decs = c.galactic.b.deg
    ras = c.galactic.l.deg
    rc = 107.2
    dc = 5.2
    
    if bank == 'A':
        cfreq = 4.575
    elif bank == 'B':
        cfreq = 5.625
    elif bank == 'C':
        cfreq = 6.125
    elif bank == 'D':
        cfreq = 7.175
    beam = 12.6 / cfreq
    
    # units
    # beam and pixbeam are in arcminutes
    beamarea = np.pi / (4. * np.log(2)) * beam**2
    pixelarea = pixbeam**2
    units = pixelarea / beamarea
    
    # ras and decs are in degrees 
    nrapix = int((ras.max() - ras.min()) / (pixbeam / 60.))
    ndecpix = int((decs.max() - decs.min()) / (pixbeam / 60.))
    
    datamap, hits, rabins, decbins = naive_map(calibrated, ras, decs, nrapix, ndecpix) 
    mask = hits == 0
    signal = np.zeros_like(datamap)
    signal[~mask] = datamap[~mask] / hits[~mask] * units
    
    radius = np.sqrt( (ras-rc)**2 + (decs-dc)**2)
    
    rmask = radius <= 1.
    insidedata = np.zeros_like(calibrated)
    insidedata[rmask] = 10.
    innermap, innerhits, rabins, decbins = naive_map(insidedata, ras, decs, nrapix, ndecpix) 
    innerregion = innermap > 0
    
    annulus = (radius >= 80./60.) & (radius <= 2.)
    outerdata = np.zeros_like(calibrated)
    outerdata[annulus] = 10.
    outermap, outerhits, rabins, decbins = naive_map(outerdata, ras, decs, nrapix, ndecpix)
    outerregion = outermap > 0
    
    if removeplane:
        rabinsc = (rabins[1:] + rabins[:-1]) / 2.
        decbinsc = (decbins[1:] + decbins[:-1]) / 2.
        X, Y = np.meshgrid(rabinsc, decbinsc)
        XX = X.flatten()
        YY = Y.flatten()
        Z = signal.flatten()
        masks = ~np.isnan(Z) * ~innerregion.flatten()
        data = np.c_[XX[masks], YY[masks], Z[masks]]
        data2 = np.c_[XX, YY, Z]
        A = np.c_[data[:, 0], data[:, 1], np.ones(data.shape[0])]
        C, _, _, _ = linalg.lstsq(A, data[:, 2])
        res = C[0] * X + C[1] * Y + C[2]
        signal -= res
        
    signal -= np.nanmedian(signal[outerregion])
    if smth is None:
        smth = beam
    if smth > 0:
        signal = gaussian_filter(signal, smth/pixbeam)
        shits = gaussian_filter(hits, smth/pixbeam)
        mask = shits < 1
    signal[mask] = np.nan
    
    if doplot:
        figure()
        pc = pcolormesh(rabinsc, decbinsc, signal * 1000.)
        clim(-15, 15)
        cb = colorbar()
        xlabel('$\mathrm{Lon}\ (deg)$')
        ylabel('$\mathrm{Lat}\ (deg)$')
        cb.set_label('$\mathrm{Flux}\ (mJy / pixel)$')
        #savefig('s4map_bank'+bank+'session'+session)
    
    print np.nansum(signal[innerregion])
    return rabinsc, decbinsc, signal

# %%
rabinsc, decbinsc, signal = calculate_sflux_gal('A', '5', smth=1.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d4eb4dd51f97> in <module>()
# ----> 1 rabinsc, decbinsc, signal = calculate_sflux_gal('A', '5', smth=1.)
#
# <ipython-input-13-1ac34057d0cf> in calculate_sflux_gal(bank, session, doplot, pixbeam, smth, removeplane)
#      12
#      13     c = coordinates.SkyCoord(frame='icrs', ra=ras*u.degree, dec=decs*u.degree)
# ---> 14     decs = c.galactic.b.deg
#      15     ras = c.galactic.l.deg
#      16     rc = 107.2
#
# /usr/lib64/python2.7/site-packages/astropy/coordinates/sky_coordinate.pyc in __getattr__(self, attr)
#     481             frame_cls = frame_transform_graph.lookup_name(attr)
#     482             if frame_cls is not None and self.frame.is_transformable_to(frame_cls):
# --> 483                 return self.transform_to(attr)
#     484
#     485         # Fail
#
# /usr/lib64/python2.7/site-packages/astropy/coordinates/sky_coordinate.pyc in transform_to(self, frame)
#     437         # Do the transformation, returning a coordinate frame of the desired
#     438         # final type (not generic).
# --> 439         new_coord = trans(self.frame, generic_frame)
#     440
#     441         # Finally make the new SkyCoord object from the `new_coord` and
#
# /usr/lib64/python2.7/site-packages/astropy/coordinates/transformations.pyc in __call__(self, fromcoord, toframe)
#     905
#     906             curr_toframe = t.tosys(**frattrs)
# --> 907             curr_coord = t(curr_coord, curr_toframe)
#     908
#     909         # this is safe even in the case where self.transforms is empty, because
#
# /usr/lib64/python2.7/site-packages/astropy/coordinates/transformations.pyc in __call__(self, fromcoord, toframe)
#     818
#     819         rep = fromcoord.represent_as(CartesianRepresentation)
# --> 820         newrep = rep.transform(transform_matrix)
#     821
#     822         if issubclass(fromcoord.data.__class__, UnitSphericalRepresentation):
#
# /usr/lib64/python2.7/site-packages/astropy/coordinates/representation.pyc in transform(self, matrix)
#     606             # Matrix multiply all pmat items and coordinates, broadcasting the
#     607             # remaining dimensions.
# --> 608             newxyz = np.einsum('...ij,j...->i...', matrix, oldxyz.value)
#     609
#     610         newxyz = u.Quantity(newxyz, oldxyz.unit, copy=False)
#
# /usr/lib64/python2.7/site-packages/numpy/core/einsumfunc.pyc in einsum(*operands, **kwargs)
#    1085     # Build the contraction list and operand
#    1086     operands, contraction_list = einsum_path(*operands, optimize=optimize_arg,
# -> 1087                                              einsum_call=True)
#    1088
#    1089     handle_out = False
#
# /usr/lib64/python2.7/site-packages/numpy/core/einsumfunc.pyc in einsum_path(*operands, **kwargs)
#     686
#     687     # Python side parsing
# --> 688     input_subscripts, output_subscript, operands = _parse_einsum_input(operands)
#     689     subscripts = input_subscripts + '->' + output_subscript
#     690
#
# /usr/lib64/python2.7/site-packages/numpy/core/einsumfunc.pyc in _parse_einsum_input(operands)
#     430                     subscripts += einsum_symbols[s]
#     431                 else:
# --> 432                     raise TypeError("For this input type lists must contain "
#     433                                     "either int or Ellipsis")
#     434             if num != last:
#
# TypeError: For this input type lists must contain either int or Ellipsis

# %%
rabinsc, decbinsc, signal = calculate_sflux_gal('A', '5', smth=None, doplot=False)
# Out:
# 34.0901809149

# %%
gridx, gridy = np.meshgrid(rabinsc, decbinsc)

# %%
pcolormesh(rabinsc, decbinsc, signal*1000)
clim(-15, 15)
cb = colorbar()
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cb.set_label('$\mathrm{Flux}\ (mJy / pixel)$')
grid()
#savefig('s4contour_mapoverlay_A5')

# %%
figure()
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
clim(-15, 15)
cb = colorbar()
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cb.set_label('$\mathrm{Flux}\ (mJy / pixel)$')
grid()
#savefig('s4contour_A5')

# %%
z = np.load('../externaldata/dustdata_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, dsig)
clim(0.00005, 0.00025)
colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
#savefig('dustopacity_gbt_contours')

# %%
z = np.load('../externaldata/planck_30_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, dsig*1000.)
#clim(0.0, 3)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$mK_{CMB}$', labelpad=10)
title('$Planck\ 30~GHz$')
grid(alpha=0.5)
#savefig('p70_gbt_contours')

# %%
z = np.load('../externaldata/planck100_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, dsig*1000.)
clim(0.0, 2.5)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$mK_{CMB}$')
savefig('p100_gbt_contours')

# %%
z = np.load('../externaldata/planck545_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, np.log(dsig))
clim(2, 5)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$MJy/sr$')
#savefig('p545_gbt_contours')

# %%
z = np.load('../externaldata/halpha_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, dsig)
clim(30, 75)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$Rayleighs$')
savefig('halpha_gbt_contours')

# %%
z = np.load('../externaldata/haslam_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, dsig / 1000.)
clim(55, 70)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$K$')
savefig('haslam_gbt_contours')

# %%
z = np.load('../externaldata/iris_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, np.log(dsig))
clim(3, 7)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$log(MJy/sr)$', labelpad=10)
title('$\mathrm{IRIS}\ 100\mu m$')
savefig('iris_gbt_contours')

# %%
z = np.load('../externaldata/wssa_gridded.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
pcolormesh(dlons, dlats, dsig)
clim(0, 30)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
#cm.set_label('$K$')
#savefig('wise_gbt_contours')

# %%
z = np.load('../externaldata/cgps.npz')
dlons = z['lons']
dlats = z['lats']
dsig = z['signal']

# %%
xmask = (dlons > gridx.min()) * (dlons < gridx.max())

# %%
ymask = (dlats > gridy.max()) * (dlats < gridy.max())

# %%
pcolormesh(dlons[xmask], dlats[ymask], dsig[xmask,:][])
clim(50, 80)
cm = colorbar();
contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
xlabel('$\mathrm{Lon}\ (deg)$')
ylabel('$\mathrm{Lat}\ (deg)$')
cm.set_label('$K$')
title('$CGPS\ 408~MHz$')
grid(alpha=0.5)
#savefig('digitized_cgps2')

# %%
24 * 365
# Out:
# 8760

# %%
import glob

# %%
fgrid = glob.glob('/home/mabitbol/GBT-S140/externaldata/*gridded.npz')
fgrid.sort()

# %%
fgrid
# Out:
# [u'/home/mabitbol/GBT-S140/externaldata/COline_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/Dustreconstructed_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/IRIS1_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/IRIS2_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/IRIS3_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/IRIS_SFD4_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/Thermaldust_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/dustdata_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/halpha2_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/halpha_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/haslam_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/iris_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck100_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck545_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_100_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_143_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_217_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_30_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_353_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_44_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_545_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_70_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_857_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_ame_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_freefree_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_hfipointsrc_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_lfipointsrc_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_opacity_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/planck_synch_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/stockert_11cm_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/stockert_1420_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/wmap_Kaband_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/wmap_Kband_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/wmap_Qband_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/wmap_Vband_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/wmap_Wband_gridded.npz',
#  u'/home/mabitbol/GBT-S140/externaldata/wssa_gridded.npz']

# %%
fgrid[10].split('/')[-1].split('gridded')[0]
# Out:
# u'haslam_'

# %%
for fn in fgrid:
    z = np.load(fn)
    dlons = z['lons']
    dlats = z['lats']
    dsig = z['signal']
    figure()
    pcolormesh(dlons, dlats, dsig)
    cm = colorbar();
    contour(gridx, gridy, signal*1000, levels=np.linspace(-10, 20, 15), cmap=matplotlib.cm.YlOrRd)
    xlabel('$\mathrm{Lon}\ (deg)$')
    ylabel('$\mathrm{Lat}\ (deg)$')
    sname = fn.split('/')[-1].split('gridded')[0] + '_gbt_contours'
    savefig(sname)
    close()
