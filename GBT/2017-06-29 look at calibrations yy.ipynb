# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
banks = ['A', 'B', 'C', 'D']

# %%
session = '01'
fs = []
power = []
power1 = []
for bank in banks:
    calibrations = np.load('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_'+bank+'.npy').item()
    fs = np.concatenate([fs, calibrations['freqs']])
    power = np.concatenate([power, calibrations['pdiode']])
    power1 = np.concatenate([power1, calibrations['pdiode1']])
z = {'freqs':fs, 'pdiode':power, 'pdiode1':power1}
np.save('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_all.npy', z)

# %%
s1p0 = power.copy()
s1p1 = power1.copy()

# %%
session = '02'
fs = []
power = []
for bank in banks:
    calibrations = np.load('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_'+bank+'.npy').item()
    fs = np.concatenate([fs, calibrations['freqs']])
    power = np.concatenate([power, calibrations['pdiode']])
z = {'freqs':fs, 'pdiode':power}
np.save('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_all.npy', z)

# %%
s2p0 = power.copy()

# %%
session = '03'
fs = []
power = []
for bank in banks:
    calibrations = np.load('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_'+bank+'.npy').item()
    fs = np.concatenate([fs, calibrations['freqs']])
    power = np.concatenate([power, calibrations['pdiode']])
z = {'freqs':fs, 'pdiode':power}
np.save('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_all.npy', z)

# %%
s3p0 = power.copy()

# %%
session = '04'
fs = []
power = []
power1 = []
power2 = []
for bank in banks:
    calibrations = np.load('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_'+bank+'.npy').item()
    fs = np.concatenate([fs, calibrations['freqs']])
    power = np.concatenate([power, calibrations['pdiode']])
    power1 = np.concatenate([power1, calibrations['pdiode1']])
    power2 = np.concatenate([power2, calibrations['pdiode2']])
z = {'freqs':fs, 'pdiode':power, 'pdiode1':power1, 'pdiode2':power2}
np.save('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_all.npy', z)

# %%
s4p0 = power.copy()
s4p1 = power1.copy()
s4p2 = power2.copy()

# %%
session = '05'
fs = []
power = []
power1 = []
for bank in banks:
    calibrations = np.load('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_'+bank+'.npy').item()
    fs = np.concatenate([fs, calibrations['freqs']])
    power = np.concatenate([power, calibrations['pdiode']])
    power1 = np.concatenate([power1, calibrations['pdiode1']])
z = {'freqs':fs, 'pdiode':power, 'pdiode1':power1}
np.save('/home/mabitbol/GBT-S140/calibrations/calibrationyy_3C295_'+session+'_all.npy', z)

# %%
s5p0 = power.copy()
s5p1 = power1.copy()

# %%
ghz = 1.e-9

# %%
figsize(8,6)
#plot(fs, s1p0, 'r', label='S1')
#plot(fs, s1p1, 'r')
plot(fs*ghz, s2p0, 'r', label='S2')
plot(fs*ghz, s3p0, 'b', label='S3')
plot(fs*ghz, s4p0, 'g', label='S4')
plot(fs*ghz, s4p1, 'g')
plot(fs*ghz, s4p2, 'g')
plot(fs*ghz, s5p0, 'cyan', label='S5')
plot(fs*ghz, s5p1, 'cyan')
ylabel('Diode power [Jy]')
legend()
xlabel('Frequency [GHz]')
grid()
ylim(2, 4)
title('Diode power calibrated on 3C295')
savefig('calibrationsyy_3C295_all')

# %%
figsize(8,6)
#plot(fs, s1p0, 'r', label='S1')
#plot(fs, s1p1, 'r')
plot(fs*ghz, s3p0/s2p0, 'b', label='S3')
plot(fs*ghz, s4p0/s2p0, 'g', label='S4')
plot(fs*ghz, s4p1/s2p0, 'g')
plot(fs*ghz, s4p2/s2p0, 'g')
plot(fs*ghz, s5p0/s2p0, 'cyan', label='S5')
plot(fs*ghz, s5p1/s2p0, 'cyan')
ylabel('ratio')
legend()
xlabel('Frequency [GHz]')
grid()
ylim(0.98, 1.1)
# Out:
# (0.98, 1.1)
