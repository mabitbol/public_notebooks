# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob

# %%
figsize(16, 10)

# %%
fnames = glob.glob('/data2/GBT/*295/OnOff/scan_01*/*rfireduced.npz')
fnames.sort()
print len(fnames)
# Out:
# 16

# %%
fnames
# Out:
# ['/data2/GBT/3C295/OnOff/scan_01_007.raw.vegas/scan_01_007.raw.vegas.A.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_007.raw.vegas/scan_01_007.raw.vegas.B.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_007.raw.vegas/scan_01_007.raw.vegas.C.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_007.raw.vegas/scan_01_007.raw.vegas.D.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_008.raw.vegas/scan_01_008.raw.vegas.A.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_008.raw.vegas/scan_01_008.raw.vegas.B.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_008.raw.vegas/scan_01_008.raw.vegas.C.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_008.raw.vegas/scan_01_008.raw.vegas.D.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_039.raw.vegas/scan_01_039.raw.vegas.A.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_039.raw.vegas/scan_01_039.raw.vegas.B.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_039.raw.vegas/scan_01_039.raw.vegas.C.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_039.raw.vegas/scan_01_039.raw.vegas.D.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_040.raw.vegas/scan_01_040.raw.vegas.A.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_040.raw.vegas/scan_01_040.raw.vegas.B.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_040.raw.vegas/scan_01_040.raw.vegas.C.fits.rfireduced.npz',
#  '/data2/GBT/3C295/OnOff/scan_01_040.raw.vegas/scan_01_040.raw.vegas.D.fits.rfireduced.npz']

# %%
for k in range(4):
    x = np.load(fnames[0+k])
    y = np.load(fnames[4+k])
    freqs = x['freqs']
    onmask = x['valid']
    offmask = y['valid']
    onSonD = x['xxon']
    onSoffD = x['xxoff']
    offSonD = y['xxon']
    offSoffD = y['xxoff']
    dioderesponse_onS = onSonD[200:,onmask] - onSoffD[200:,onmask]
    dioderesponse_offS = offSonD[200:,offmask] - offSoffD[200:,offmask]
    sourceresponse_onD = onSonD[200:,offmask] - offSonD[200:,offmask]
    sourceresponse_offD = onSoffD[200:,offmask] - offSoffD[200:,offmask]
    plot(freqs[onmask], (np.nanmean(dioderesponse_onS, 0) - np.nanmean(dioderesponse_offS, 0))\
         / np.nanmean(dioderesponse_offS, 0))
ylim([-0.01, 0.03])
# Out:
# (-0.01, 0.03)

# %%
for k in range(4):
    x = np.load(fnames[8+k])
    y = np.load(fnames[12+k])
    freqs = x['freqs']
    onmask = x['valid']
    offmask = y['valid']
    onSonD = x['xxon']
    onSoffD = x['xxoff']
    offSonD = y['xxon']
    offSoffD = y['xxoff']
    dioderesponse_onS = onSonD[200:,onmask] - onSoffD[200:,onmask]
    dioderesponse_offS = offSonD[200:,offmask] - offSoffD[200:,offmask]
    sourceresponse_onD = onSonD[200:,offmask] - offSonD[200:,offmask]
    sourceresponse_offD = onSoffD[200:,offmask] - offSoffD[200:,offmask]
    plot(freqs[onmask], (np.nanmean(dioderesponse_onS, 0) - np.nanmean(dioderesponse_offS, 0))\
         / np.nanmean(dioderesponse_offS, 0))
ylim([0, 0.03])
# Out:
# (0, 0.03)

# %%
fnames = glob.glob('/data2/GBT/*295/OnOff/scan_02*/*rfireduced.npz')
fnames.sort()
print len(fnames)
# Out:
# 8

# %%
for k in range(4):
    x = np.load(fnames[0+k])
    y = np.load(fnames[4+k])
    freqs = x['freqs']
    onmask = x['valid']
    offmask = y['valid']
    onSonD = x['xxon']
    onSoffD = x['xxoff']
    offSonD = y['xxon']
    offSoffD = y['xxoff']
    dioderesponse_onS = onSonD[200:,onmask] - onSoffD[200:,onmask]
    dioderesponse_offS = offSonD[200:,offmask] - offSoffD[200:,offmask]
    sourceresponse_onD = onSonD[200:,offmask] - offSonD[200:,offmask]
    sourceresponse_offD = onSoffD[200:,offmask] - offSoffD[200:,offmask]
    plot(freqs[onmask], (np.nanmean(dioderesponse_onS, 0) - np.nanmean(dioderesponse_offS, 0))\
         / np.nanmean(dioderesponse_offS, 0))
    
ylim([-0.01, 0.03])
# Out:
# (-0.01, 0.03)

# %%
fnames = glob.glob('/data2/GBT/*295/OnOff/scan_03*/*rfireduced.npz')
fnames.sort()
print len(fnames)
# Out:
# 8

# %%
for k in range(4):
    x = np.load(fnames[0+k])
    y = np.load(fnames[4+k])
    freqs = x['freqs']
    onmask = x['valid']
    offmask = y['valid']
    onSonD = x['xxon']
    onSoffD = x['xxoff']
    offSonD = y['xxon']
    offSoffD = y['xxoff']
    dioderesponse_onS = onSonD[200:,onmask] - onSoffD[200:,onmask]
    dioderesponse_offS = offSonD[200:,offmask] - offSoffD[200:,offmask]
    sourceresponse_onD = onSonD[200:,offmask] - offSonD[200:,offmask]
    sourceresponse_offD = onSoffD[200:,offmask] - offSoffD[200:,offmask]
    plot(freqs[onmask], (np.nanmean(dioderesponse_onS, 0) - np.nanmean(dioderesponse_offS, 0))\
         / np.nanmean(dioderesponse_offS, 0))
ylim([-0.01, 0.03])
# Out:
# (-0.01, 0.03)
