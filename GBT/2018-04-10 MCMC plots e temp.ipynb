# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd /home/mabitbol/GBT-S140/analysis/
# Out:
# /home/mabitbol/GBT-S140/analysis

# %%
import foregrounds as fg
from scipy.optimize import curve_fit
import emcee
import corner

# %%
from __future__ import unicode_literals

figsize(16, 10)

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
    
rcParams['xtick.labelsize'] = 20
rcParams['xtick.major.size'] = 10
rcParams['xtick.major.width'] = 1
rcParams['xtick.major.pad'] = 0
rcParams['xtick.minor.size'] = 5
rcParams['xtick.minor.width'] = 1

rcParams['ytick.labelsize'] = 20
rcParams['ytick.major.size'] = 10
rcParams['ytick.major.width'] = 1
rcParams['ytick.major.pad'] = 0
rcParams['ytick.minor.size'] = 5
rcParams['ytick.minor.width'] = 1

rcParams['legend.fontsize'] = 24
rcParams['legend.borderaxespad'] = 1

rcParams['axes.labelsize'] = 24
rcParams['axes.titlesize'] = 24
rcParams['axes.labelpad'] = 10

# %%
bigfs = np.array([  4.08000000e+08,   1.42000000e+09,   4.57500000e+09,
         5.62500000e+09,   6.12500000e+09,   2.84000000e+10,
         4.41000000e+10,   7.04000000e+10,   1.43000000e+11,
         3.53000000e+11,   5.45000000e+11,   8.57000000e+11,
         1.25000000e+12,   2.14200000e+12,   3.00000000e+12])

# %%
bigdata = np.array([  1.69932098e+01,   1.88907320e+01,   1.80860056e+01,
         1.75061433e+01,   1.77466662e+01,   3.02925356e+01,
         2.67933107e+01,   2.61128183e+01,   8.87159628e+01,
         1.55447367e+03,   5.19328227e+03,   1.80570130e+04,
         4.39553844e+04,   7.45743649e+04,   4.19317749e+04])

# %%
bigerrs = np.array([  2.63219005e+00,   1.98121311e+00,   1.81,
         1.75,   1.76,   1.16505200e+00,
         1.09064996e+00,   1.29007422e+00,   4.88926217e+00,
         7.13450484e+01,   2.27787009e+02,   7.40880194e+02,
         1.14919453e+03,   1.56319215e+03,   8.11448565e+02])

# %%
beam = pi*((45./60.)*pi/180.)**2
beam2 = pi*((1./60./60.)*pi/180.)**2

# %%
def signal2(freqs, EM1, EM2, Te, abeam, Ad, Bd, Td, Acmb):
    fffit = fg.freefreep(freqs, EM=EM1, Te=8000) * beam
    fffit2 = fg.freefreep(freqs, EM=EM2, Te=Te) * abeam
    dustfit = fg.thermal_dust(freqs, Ad=Ad, Bd=Bd, Td=Td) * beam
    ccmb = fg.cmb(freqs, A=Acmb) * beam
    return fffit + fffit2 + dustfit + ccmb

# %%
pn2 = np.array([100., 1.e9, 1.e4, 5.e-10, 1.e-4, 2., 20., 30e-6])
y = curve_fit(signal2, bigfs, bigdata, p0=pn2, sigma=bigerrs, absolute_sigma=True)
pfit4 = y[0]

# %%
figsize(8, 6)

# %%
def lnprior2(theta):
    EM1, EM2, Te, abeam, Ad, Bd, Td, Acmb = theta
    if EM1 < 0 or EM1 > 1e4:
        return np.inf
    if EM2 < 1e4 or EM2 > 1e11:
        return np.inf
    if Te < 10 or Te>1e8:
        return np.inf
    if abeam < 0 or abeam > 1e-5:
        return np.inf
    if Ad < 0 or Ad > 10:
        return np.inf
    if Bd < 0 or Bd > 10:
        return np.inf
    if Td < 1 or Td > 100:
        return np.inf
    if np.abs(Acmb) > 10:
        return np.inf
    return 0.

# %%
def lnprob2(theta, x, y, yerr):
    lp = lnprior2(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike2(theta, x, y, yerr)

# %%
def lnlike2(theta, x, y, yerr):
    EM1, EM2, Te, abeam, Ad, Bd, Td, Acmb = theta
    fffit = fg.freefreep(x, EM=EM1, Te=8000.) * beam
    fffit2 = fg.freefreep(x, EM=EM2, Te=Te) * abeam
    dustfit = fg.thermal_dust(x, Ad=Ad, Bd=Bd, Td=Td) * beam
    ccmb = fg.cmb(x, A=Acmb) * beam
    model = fffit + fffit2 + dustfit + ccmb
    return -0.5 * np.sum((y-model)**2 / (yerr**2))

# %%
ndim, nwalkers = 8, 128
pos = [pfit4 * (1. + 1.e-3*np.random.randn(ndim)) for i in range(nwalkers)]

# %%
sampler1 = emcee.EnsembleSampler(nwalkers, ndim, lnprob2, args=(bigfs, bigdata, bigerrs))

# %%
sampler1.run_mcmc(pos, 2**14);
# Out:
# /usr/lib/python2.7/site-packages/ipykernel/__main__.py:8: RuntimeWarning: overflow encountered in square

# %%
figsize(8, 6)
for k in range(ndim):
    figure()
    plot(sampler1.chain[:,::100,k].T, color='k', alpha=0.1);

# %%
samples1 = sampler1.chain[:, 10000:, :].reshape((-1, ndim))

# %%
datas = samples1.copy()

# %%
datas[:, 1] *= 1e-8
datas[:, 2] = np.sqrt( datas[:, 2] / pi) * 180. / pi * 60. * 60.
datas[:, 3] *= 1e6
datas[:, 6] *= 1e6

# %%
fig = corner.corner(datas, plot_datapoints=False, bins=100, levels=[0.68,0.95], smooth=1., \
                    labels=["$\mathrm{EM_{Diffuse}}$\n [$\mathrm{cm^{-6} pc}$]", 
                            "$\mathrm{EM_{UCHII}}$\n [$\\times 10^8 \mathrm{cm^{-6} pc}$]", 
                            "Te"
                            "$\mathrm{\\theta_{UCHII}}$\n [$\mathrm{arcseconds}$]",
                            "$\mathrm{A_{D}}$\n [$\mathrm{\mu K}$]", 
                            "$\mathrm{\\beta_{D}}$\n [$-$]", 
                            "$\mathrm{T_{D}}$\n [$\mathrm{K}$]", 
                            "$\mathrm{A_{CMB}}$\n [$\mathrm{\mu K}$]"], \
                    color='midnightblue', max_n_ticks=4)
#savefig('/home/mabitbol/GBT-S140/notebooks/UCHII_posterior.pdf', format='pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-44a4bafd002a> in <module>()
#       7                             "$\mathrm{T_{D}}$\n [$\mathrm{K}$]",
#       8                             "$\mathrm{A_{CMB}}$\n [$\mathrm{\mu K}$]"], \
# ----> 9                     color='midnightblue', max_n_ticks=4)
#      10 #savefig('/home/mabitbol/GBT-S140/notebooks/UCHII_posterior.pdf', format='pdf', bbox_inches='tight')
#
# /usr/lib/python2.7/site-packages/corner/corner.pyc in corner(xs, bins, range, weights, color, smooth, smooth1d, labels, label_kwargs, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, hist_kwargs, **hist2d_kwargs)
#     331             hist2d(y, x, ax=ax, range=[range[j], range[i]], weights=weights,
#     332                    color=color, smooth=smooth, bins=[bins[j], bins[i]],
# --> 333                    **hist2d_kwargs)
#     334
#     335             if truths is not None:
#
# /usr/lib/python2.7/site-packages/corner/corner.pyc in hist2d(x, y, bins, range, weights, levels, smooth, ax, color, plot_datapoints, plot_density, plot_contours, no_fill_contours, fill_contours, contour_kwargs, contourf_kwargs, data_kwargs, **kwargs)
#     597     # contour fills.
#     598     elif plot_density:
# --> 599         ax.pcolor(X, Y, H.max() - H.T, cmap=density_cmap)
#     600
#     601     # Plot the contour edge colors.
#
# /usr/lib64/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /usr/lib64/python2.7/site-packages/matplotlib/axes/_axes.pyc in pcolor(self, *args, **kwargs)
#    5434         kwargs.setdefault('snap', False)
#    5435
# -> 5436         collection = mcoll.PolyCollection(verts, **kwargs)
#    5437
#    5438         collection.set_alpha(alpha)
#
# /usr/lib64/python2.7/site-packages/matplotlib/collections.pyc in __init__(self, verts, sizes, closed, **kwargs)
#     912         Collection.__init__(self, **kwargs)
#     913         self.set_sizes(sizes)
# --> 914         self.set_verts(verts, closed)
#     915         self.stale = True
#     916
#
# /usr/lib64/python2.7/site-packages/matplotlib/collections.pyc in set_verts(self, verts, closed)
#     928                     else:
#     929                         xy = np.asarray(xy)
# --> 930                         xy = np.concatenate([xy, xy[0:1]])
#     931                     codes = np.empty(xy.shape[0], dtype=mpath.Path.code_type)
#     932                     codes[:] = mpath.Path.LINETO
#
# KeyboardInterrupt:

# %%
np.save('mcmc_uchii_samples', datas)

# %%
print "EM1, EM2, abeam, Ad, Bd, Td, Acmb"
map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]), zip(*np.percentile(datas, [16, 50, 84], axis=0)))
# Out:
# EM1, EM2, abeam, Ad, Bd, Td, Acmb
# [(295.47342036379251, 22.790524344228913, 22.195003893063017),
#  (374.66613226210785, 425.17700666462673, 344.88098300819388),
#  (52197588.003169112, 18591141.087102138, 32309603.074587107),
#  (1.9700799155848011e-05, 0.00011037891739765785, 8.4622413350595868e-06),
#  (0.0011580541134052962, 2.6744717524488162e-05, 2.7620086644525874e-05),
#  (1.8341686319630801, 0.058144991103685539, 0.059557116109751895),
#  (19986495.472622272, 365274.14778574556, 353100.59071414173),
#  (-2.7724714758986279e-05, 2.8222739098718163e-05, 2.9253326610472736e-05)]

# %%
vds = zip(*np.percentile(datas, [16, 50, 84], axis=0))

# %%
names = ["EM1", "EM2", "abeam", "Ad", "Bd", "Td", "Acmb"]

# %%
for k in range(len(vds)):
    print names[k], '{0:1.3g}'.format(vds[k][1]), '{0:1.2g}'.format(vds[k][2] - vds[k][1]), \
          '{0:1.2g}'.format(vds[k][1] - vds[k][0], 1)
# Out:
# EM1 300 22 24
# EM2 5.27 2.5 1.5
# abeam 2.49 0.47 0.44
# Ad 1.16e+03 27 27
# Bd 1.83 0.057 0.056
# Td 20 0.35 0.34
# Acmb -20.9 27 28
