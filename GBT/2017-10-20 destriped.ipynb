# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astropy.io import fits

# %%
from scipy.ndimage.filters import gaussian_filter

# %%
figsize(8, 6)

# %%
x = fits.open('/home/mabitbol/GBT-S140/externaldata/destripingdata_bankA_session5_weights.fits')

# %%
signal = x[0].data

# %%
smth = 2.75 / 0.583

# %%
mask = x[0].data == 0

# %%
signal = gaussian_filter(signal, smth)

# %%
signal[mask] = np.nan

# %%
imshow(x[0].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[3].data)
colorbar()
clim(0, 3)

# %%
imshow(x[5].data)
colorbar()
clim(0, 360)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-6457d02cf27b> in <module>()
# ----> 1 imshow(x[5].data)
#       2 colorbar()
#       3 clim(0, 360)
#
# /usr/lib64/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in __getitem__(self, key)
#     312         # instead
#     313         return self._try_while_unread_hdus(super(HDUList, self).__getitem__,
# --> 314                                            self._positive_index_of(key))
#     315
#     316     def __contains__(self, item):
#
# /usr/lib64/python2.7/site-packages/astropy/io/fits/hdu/hdulist.pyc in _try_while_unread_hdus(self, func, index, *args, **kwargs)
#    1093         while True:
#    1094             try:
# -> 1095                 return func(index, *args, **kwargs)
#    1096             except Exception:
#    1097                 if self._read_next_hdu():
#
# ...

# %%
imshow(x[1].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data - x[0].data)
colorbar()
clim(-0.1, 0.15)

# %%
x = fits.open('/home/mabitbol/GBT-S140/externaldata/destripingdata_bankB_session5.fits')

# %%
imshow(x[0].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data - x[0].data)
colorbar()
clim(-0.1, 0.1)

# %%
x = fits.open('/home/mabitbol/GBT-S140/externaldata/destripingdata_bankC_session5.fits')

# %%
imshow(x[0].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data - x[0].data)
colorbar()
clim(-0.1, 0.15)

# %%
x = fits.open('/home/mabitbol/GBT-S140/externaldata/destripingdata_bankD_session5.fits')

# %%
imshow(x[0].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data)
colorbar()
clim(-0.1, 0.15)

# %%
imshow(x[1].data - x[0].data)
colorbar()
clim(-0.1, 0.15)
