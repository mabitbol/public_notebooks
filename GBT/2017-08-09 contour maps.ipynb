# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import glob
from scipy.ndimage.filters import gaussian_filter
from scipy.optimize import curve_fit

# %%
import healpy as hp

# %%
from astropy import coordinates
from astropy import units as u
from astropy.coordinates import ICRS

# %%
figsize(10, 8)

# %%
freqs = [4.575, 5.625, 6.125, 7.175]
banks = ['A', 'B', 'C', 'D']

# %%
rc = 335.7133441444117
dc = 63.43802542905474

# %%
def naive_map(data,ra,dec,ra_num_bins=60,dec_num_bins=50):
    ra_bins = np.linspace(ra.min(),ra.max(),ra_num_bins)
    dec_bins = np.linspace(dec.min(),dec.max(),dec_num_bins)
    p,_,_ = np.histogram2d(ra,dec,bins=(ra_bins,dec_bins),weights=data)
    hits,_,_ = np.histogram2d(ra,dec,bins=(ra_bins,dec_bins))
    return p.T, hits.T, ra_bins, dec_bins

# %%
def calculate_sflux(bank='A', session='5', doplot=True, pixbeam=1., smth=0, removeplane=True):
    #dataf = np.load('/home/mabitbol/GBT-S140/datamaps/datamaps_'+bank+'_'+session+'.npz')
    dataf = np.load('/home/mabitbol/GBT-S140/datamaps/tod'+bank+'_'+session+'.npz')
    tmask = dataf['tmask']
    ras = dataf['ras'][tmask]
    decs = dataf['decs'][tmask]
    calibrated = dataf['calibrated'][tmask]
    
    tmask2 = ~np.isnan(calibrated)
    ras = ras[tmask2]
    decs = decs[tmask2]
    calibrated = calibrated[tmask2] 
    
    if bank == 'A':
        cfreq = 4.575
    elif bank == 'B':
        cfreq = 5.625
    elif bank == 'C':
        cfreq = 6.125
    elif bank == 'D':
        cfreq = 7.175
    beam = 12.6 / cfreq
    
    # units
    # beam and pixbeam are in arcminutes
    beamarea = np.pi / (4. * np.log(2)) * beam**2
    pixelarea = pixbeam**2
    units = pixelarea / beamarea
    
    # ras and decs are in degrees 
    nrapix = int((ras.max() - ras.min()) / (pixbeam / 60.))
    ndecpix = int((decs.max() - decs.min()) / (pixbeam / 60.))
    
    datamap, hits, rabins, decbins = naive_map(calibrated, ras, decs, nrapix, ndecpix) 
    mask = hits == 0
    signal = np.zeros_like(datamap)
    signal[~mask] = datamap[~mask] / hits[~mask] * units
    
    radius = np.sqrt( (ras-rc)**2 + (decs-dc)**2)
    
    rmask = radius <= 1.
    insidedata = np.zeros_like(calibrated)
    insidedata[rmask] = 10.
    innermap, innerhits, rabins, decbins = naive_map(insidedata, ras, decs, nrapix, ndecpix) 
    innerregion = innermap > 0
    
    annulus = (radius >= 80./60.) & (radius <= 2.)
    outerdata = np.zeros_like(calibrated)
    outerdata[annulus] = 10.
    outermap, outerhits, rabins, decbins = naive_map(outerdata, ras, decs, nrapix, ndecpix)
    outerregion = outermap > 0
    
    if removeplane:
        rabinsc = (rabins[1:] + rabins[:-1]) / 2.
        decbinsc = (decbins[1:] + decbins[:-1]) / 2.
        X, Y = np.meshgrid(rabinsc, decbinsc)
        XX = X.flatten()
        YY = Y.flatten()
        Z = signal.flatten()
        masks = ~np.isnan(Z) * (~innerregion.flatten()) * (~outerregion.flatten())
        data = np.c_[XX[masks], YY[masks], Z[masks]]
        data2 = np.c_[XX, YY, Z]
        A = np.c_[data[:, 0], data[:, 1], np.ones(data.shape[0])]
        C, _, _, _ = linalg.lstsq(A, data[:, 2])
        res = C[0] * X + C[1] * Y + C[2]
        signal -= res
        
    signal -= np.nanmedian(signal[outerregion])
    if smth is None:
        smth = beam
    if smth > 0:
        signal = gaussian_filter(signal, smth/pixbeam)
        shits = gaussian_filter(hits, smth/pixbeam)
        mask = shits < 1
    signal[mask] = np.nan
    
    if doplot:
        figure()
        pc = pcolormesh(rabins, decbins, signal)
        clim(-0.1*units, 0.1*units)
        cb = colorbar()
        xlabel('RA [degrees]')
        ylabel('DEC [degrees]')
        cb.set_label('Flux [Jy/pixel]')
        title('Bank '+bank)
        
    print np.nansum(signal[innerregion])
    return rabinsc, decbinsc, signal

# %%
def calculate_sflux_gal(bank='A', session='5', doplot=True, pixbeam=1., smth=0, removeplane=True):
    #dataf = np.load('/home/mabitbol/GBT-S140/datamaps/datamaps_'+bank+'_'+session+'.npz')
    dataf = np.load('/home/mabitbol/GBT-S140/datamaps/tod'+bank+'_'+session+'.npz')
    tmask = dataf['tmask']
    ras = dataf['ras'][tmask]
    decs = dataf['decs'][tmask]
    calibrated = dataf['calibrated'][tmask]
    
    tmask2 = ~np.isnan(calibrated)
    ras = ras[tmask2]
    decs = decs[tmask2]
    calibrated = calibrated[tmask2] 
    
    c = coordinates.SkyCoord(frame='icrs', ra=ras*u.degree, dec=decs*u.degree)
    decs = c.galactic.b.deg
    ras = c.galactic.l.deg
    rc = 107.2
    dc = 5.2
    
    if bank == 'A':
        cfreq = 4.575
    elif bank == 'B':
        cfreq = 5.625
    elif bank == 'C':
        cfreq = 6.125
    elif bank == 'D':
        cfreq = 7.175
    beam = 12.6 / cfreq
    
    # units
    # beam and pixbeam are in arcminutes
    beamarea = np.pi / (4. * np.log(2)) * beam**2
    pixelarea = pixbeam**2
    units = pixelarea / beamarea
    
    # ras and decs are in degrees 
    nrapix = int((ras.max() - ras.min()) / (pixbeam / 60.))
    ndecpix = int((decs.max() - decs.min()) / (pixbeam / 60.))
    
    datamap, hits, rabins, decbins = naive_map(calibrated, ras, decs, nrapix, ndecpix) 
    mask = hits == 0
    signal = np.zeros_like(datamap)
    signal[~mask] = datamap[~mask] / hits[~mask] * units
    
    radius = np.sqrt( (ras-rc)**2 + (decs-dc)**2)
    
    rmask = radius <= 1.
    insidedata = np.zeros_like(calibrated)
    insidedata[rmask] = 10.
    innermap, innerhits, rabins, decbins = naive_map(insidedata, ras, decs, nrapix, ndecpix) 
    innerregion = innermap > 0
    
    annulus = (radius >= 80./60.) & (radius <= 2.)
    outerdata = np.zeros_like(calibrated)
    outerdata[annulus] = 10.
    outermap, outerhits, rabins, decbins = naive_map(outerdata, ras, decs, nrapix, ndecpix)
    outerregion = outermap > 0
    
    if removeplane:
        rabinsc = (rabins[1:] + rabins[:-1]) / 2.
        decbinsc = (decbins[1:] + decbins[:-1]) / 2.
        X, Y = np.meshgrid(rabinsc, decbinsc)
        XX = X.flatten()
        YY = Y.flatten()
        Z = signal.flatten()
        masks = ~np.isnan(Z) * (~innerregion.flatten()) * (~outerregion.flatten())
        data = np.c_[XX[masks], YY[masks], Z[masks]]
        data2 = np.c_[XX, YY, Z]
        A = np.c_[data[:, 0], data[:, 1], np.ones(data.shape[0])]
        C, _, _, _ = linalg.lstsq(A, data[:, 2])
        res = C[0] * X + C[1] * Y + C[2]
        signal -= res
        
    signal -= np.nanmedian(signal[outerregion])
    if smth is None:
        smth = beam
    if smth > 0:
        signal = gaussian_filter(signal, smth/pixbeam)
        shits = gaussian_filter(hits, smth/pixbeam)
        mask = shits < 1
    signal[mask] = np.nan
    
    if doplot:
        figure()
        pc = pcolormesh(rabins, decbins, signal)
        clim(-0.1*units, 0.1*units)
        cb = colorbar()
        xlabel('LON [degrees]')
        ylabel('LAT [degrees]')
        cb.set_label('Flux [Jy/pixel]')
        title('Bank '+bank)

    return rabinsc, decbinsc, signal

# %%
ras, decs, signal = calculate_sflux_gal()

# %%
ras, decs, signal = calculate_sflux(session='3', smth=0)
# Out:
# 40.5065668137

# %%
ras, decs, signal = calculate_sflux(session='2', smth=0)
# Out:
# 38.2461954323

# %%
ras, decs, signal = calculate_sflux(smth=0)
# Out:
# 38.2461724605

# %%
ras, decs, signal = calculate_sflux(smth=0)
# Out:
# 38.1918970118

# %%
ras, decs, signal = calculate_sflux(smth=None)
# Out:
# 37.945833545

# %%
gridx, gridy = np.meshgrid(ras, decs)

# %%
pcolormesh(lons, lats, signal)
clim(-0.015, 0.015)
cm = colorbar();
#contour(gridx, gridy, signal, cmap=cm.cmap)

# %%
dustmap = hp.read_map('/home/mabitbol/GBT-S140/externaldata/COM_CompMap_Dust-GNILC-Model-Opacity_2048_R2.00.fits')
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file

# %%
lonc = 107.2
latc = 5.2
lonra = [lons.min(), lons.max()]
latra = [lats.min(), lats.max()]

# %%
x = hp.cartview(dustmap, lonra=lonra, latra=latra, flip='geo', return_projected_map=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3a268ab5a356> in <module>()
# ----> 1 x = hp.cartview(dustmap, lonra=lonra, latra=latra, flip='geo', return_projected_map=True)
#
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/visufunc.pyc in cartview(map, fig, rot, zat, coord, unit, xsize, ysize, lonra, latra, title, nest, remove_dip, remove_mono, gal_cut, min, max, flip, format, cbar, cmap, norm, aspect, hold, sub, margins, notext, return_projected_map)
#     539         img = ax.projmap(map,nest=nest,coord=coord,vmin=min,vmax=max,
#     540                    xsize=xsize,ysize=ysize,lonra=lonra,latra=latra,
# --> 541                    cmap=cmap,norm=norm,aspect=aspect)
#     542         if cbar:
#     543             im = ax.get_images()[0]
#
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/projaxes.pyc in projmap(self, map, nest, **kwds)
#     664         nside = pixelfunc.npix2nside(pixelfunc.get_map_size(map))
#     665         f = lambda x,y,z: pixelfunc.vec2pix(nside,x,y,z,nest=nest)
# --> 666         return super(HpxCartesianAxes,self).projmap(map,f,**kwds)
#     667
#     668
#
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/projaxes.pyc in projmap(self, map, vec2pix_func, xsize, ysize, lonra, latra, **kwds)
#     657
#     658     def projmap(self,map,vec2pix_func,xsize=800,ysize=None,lonra=None,latra=None,**kwds):
# --> 659         self.proj.set_proj_plane_info(xsize=xsize,ysize=ysize,lonra=lonra,latra=latra)
#     660         return super(CartesianAxes,self).projmap(map,vec2pix_func,**kwds)
#     661
#
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/projector.pyc in set_proj_plane_info(self, xsize, ysize, lonra, latra)
#     555         if (len(lonra)!=2 or len(latra)!=2 or lonra[0]<-180. or lonra[1]>180.
#     556             or latra[0]<-90 or latra[1]>90 or lonra[0]>=lonra[1] or latra[0]>=latra[1]):
# --> 557             raise TypeError("Wrong argument lonra or latra. Must be lonra=[a,b],latra=[c,d] "
#     558                             "with a<b, c<d, a>=-180, b<=180, c>=-90, d<=+90")
#     559         lonra = self._flip*np.float64(lonra)[::self._flip]
#
# TypeError: Wrong argument lonra or latra. Must be lonra=[a,b],latra=[c,d] with a<b, c<d, a>=-180, b<=180, c>=-90, d<=+90

# %%
imshow(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-cc354a326c94> in <module>()
# ----> 1 imshow(x)
#
# NameError: name 'x' is not defined

# %%
theta = ( 90. - lats) * (np.pi / 180.)

# %%
phi = -lons

# %%
hp.ang2pix(2048, theta, phi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5c6be67c0d3b> in <module>()
# ----> 1 hp.ang2pix(2048, theta, phi)
#
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/pixelfunc.pyc in ang2pix(nside, theta, phi, nest)
#     367         return pixlib._ang2pix_nest(nside,theta,phi)
#     368     else:
# --> 369         return pixlib._ang2pix_ring(nside,theta,phi)
#     370
#     371 def pix2ang(nside,ipix,nest=False):
#
# ValueError: operands could not be broadcast together with shapes () (167,) (401,)

# %%
pcolormesh(lons, lats, signal)
clim(-0.01, 0.01)
cm = colorbar();
contour(gridx, gridy, signal, levels=np.linspace(-0.01, 0.02, 15))
xlabel('RA [degrees]')
ylabel('DEC [degrees]')
cm.set_label('Flux [Jy/pixel]')
savefig('figures/contourmaptest')

# %%
contour(gridx, gridy, signal, levels=np.linspace(-0.01, 0.02, 15))
grid()
colorbar()
