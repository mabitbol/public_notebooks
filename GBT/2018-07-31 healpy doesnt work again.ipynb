# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import healpy as hp
# Out:
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/sphtfunc.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   import _sphtools as _sphtools
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/__init__.py:54: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from _query_disc import query_disc, query_strip, query_polygon, boundaries
# /home/mabitbol/.local/lib/python2.7/site-packages/healpy/__init__.py:58: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from _pixelfunc import ringinfo, pix2ring

# %%
x, y = hp.read_map('/home/mabitbol/notebooks/aether_notebooks/Thesis/COM_CompMap_DustPol-commander_1024_R2.00.fits', field=(0, 1))
# Out:
# NSIDE = 1024
# ORDERING = NESTED in fits file
# Ordering converted to RING
# Ordering converted to RING

# %%
P = np.sqrt(x*x + y*y)

# %%
hp.mollview(P, norm='log')
