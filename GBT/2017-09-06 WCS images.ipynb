# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astropy.wcs import WCS

# %%
from astropy.io import fits

# %%
hdu = fits.open('../externaldata/new-image.fits')[0]
wcs = WCS(hdu.header)

# %%
fig = figure(figsize=(16, 10))
fig.add_subplot(111, projection=wcs)
imshow(hdu.data, origin='lower', cmap=cm.viridis)
xlabel('RA')
ylabel('Dec')

# %%
cgpsfits = fits.open('../externaldata/g107.2_cgps408.fits')

# %%
cgpsfits[0].header
# Out:
# SIMPLE  =                    T          / STANDARD FITS TAPE
# BITPIX  =                  -32          / IEEE FLOATING POINT
# NAXIS   =                    4          / NUMBER OF AXES
# NAXIS1  =                  256          / # PIXELS PER ROW (E.G. RA)
# NAXIS2  =                  256          / # ROWS (E.G. DEC)
# NAXIS3  =                    1          / THIRD COORDINATE
# NAXIS4  =                    1          / STOKES (BEAM=0,I,Q,U,V,OTHER=5)
#
#
# BLOCKED =                    T          / TAPE MAY BE BLOCKED
#
#
#
# BSCALE  =       0.10000000E+01          / REAL=TAPE*BSCALE+BZERO
# BZERO   =       0.00000000E+00          /
# DATE    = '2017-08-24                  '/ TAPE WRITING DATE
# FILENAME= 'I408.G107.2                 '/ DRAO FILENAME
#
#
#
# DATAMIN =       0.47595047E+02          / MINIMUM PIXELVALUE IN FILES
# DATAMAX =       0.48916251E+03          / MAXIMUM PIXELVALUE IN FILES
# MINCOL  =                  252          / COLUMN POSITION OF MIN VALUE
# MAXCOL  =                  100          / COLUMN POSITION OF MAX VALUE
# MINROW  =                  251          / ROW POSITION OF MIN VALUE
# MAXROW  =                   47          / ROW POSITION OF MAX VALUE
#
#
# OBJECT  = 'G107.2+5.2 (CGPS 408 MHz)   '/ OBJECT NAME
# ORIGIN  = 'DRAO                        '/ TAPE WRITING INSTITUTION
# INSTRUME= 'DRAO SST                    '/ DATA ACQUISITION INSTRUMENT
# OBSERVER= 'UNKNOWN                     '/ OBSERVER NAME/ID
# DATE-OBS= '2005-01-01                  '/ DATE OBSERVED
# BUNIT   = 'K_Tb                        '/ BRIGHTNESS UNITS
#
#
# EQUINOX =       0.19500000E+04          / EQUINOX OF COORDINATE SYSTEM (YRS)
# CTYPE1  = 'GLON-CAR                    '/ COORD TYPE: GAL LONGITUDE (DEG)
# CRVAL1  =       0.10720000E+03          / REF COORD VALUE (DEG)
# CRPIX1  =       0.12900000E+03          / REF POINT PIXEL
# CDELT1  =      -0.16666666E-01          / COORD VALUE INCREMENT (DEG)
# CROTA1  =       0.00000000E+00          / CCW ROTATES -GLON INTO +GLAT
# CTYPE2  = 'GLAT-CAR                    '/ COORD TYPE: GAL LATITUDE (DEG)
# CRVAL2  =       0.52000003E+01          / REF COORD VALUE (DEG)
# CRPIX2  =       0.12900000E+03          / REF POINT PIXEL
# CDELT2  =       0.12499999E-01          / COORD VALUE INCREMENT (DEG)
# CROTA2  =       0.00000000E+00          / CCW ROTATES +GLAT INTO +GLON
# CTYPE3  = 'FREQ                        '/ COORD TYPE: FREQ (HZ)
# CRVAL3  =       0.40800000E+09          / REF COORD VALUE (HZ)
# CRPIX3  =       0.10000000E+01          / REF POINT PIXEL
# CDELT3  =       0.10000000E+01          / COORD VALUE INCREMENT (HZ)
# CROTA3  =       0.00000000E+00          / ROTATION: UNDEFINED
# CTYPE4  = 'STOKES                      '/ COORD TYPE: STOKES PARAM
# CRVAL4  =       0.10000000E+01          / REF POINT VAL: 0-5=BM,I,Q,U,V,OTHER
# CRPIX4  =       0.10000000E+01          / REF POINT
# CDELT4  =       0.10000000E+01          / COORD VALUE INCREMENT
# CROTA4  =       0.00000000E+00          / STOKES ROTATION UNDEFINED
# OBSFREQ =       0.40800000E+09          / OBSERVING FREQUENCY (HZ)
# BANDW   =       0.10000000E+07          / EFFECTIVE BANDWIDTH (HZ)
#
#
#
#
# OBSRA   =       0.33530231E+03          / POINTING CENTRE R.A. (DEGREES)
# OBSDEC  =       0.63184677E+02          / POINTING CENTRE DEC. (DEGREES)
# UVGRID  = 'GAUSSIAN                    '/ CONVOLVING FUNCTION CODE
# BLGRAD  = 'GAUSSIAN TO 20%             '/ BASELINE GRADING CODE
# POLCODE = 'I                           '/ STOKES COMBINATION (OTHER)
#
# MAXBAS  =                600.0          / MAXIMUM BASELINE USED IN MAP (M)
# MINBAS  =                 12.8          / MINIMUM BASELINE USED IN MAP (M)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# HISTORY   Last changed by: supertile        on 24-AUG-2017
